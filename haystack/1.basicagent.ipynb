# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
from getpass import getpass
import os

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass("Enter OpenAI API key:")
if "SERPERDEV_API_KEY" not in os.environ:
    os.environ["SERPERDEV_API_KEY"] = getpass("a60f82a5924786f7b34cf8407fa42c89256e95f8")

# %% [markdown]
# # Using Agent with a Component as a Tool

# %%
from haystack.components.agents import Agent
from haystack.components.generators.chat import OpenAIChatGenerator
from haystack.components.websearch import SerperDevWebSearch
from haystack.dataclasses import ChatMessage
from haystack.tools.component_tool import ComponentTool

# Create a web search tool using SerperDevWebSearch
web_tool = ComponentTool(component=SerperDevWebSearch(), name="web_tool")

# Create the agent with the web search tool
agent = Agent(chat_generator=OpenAIChatGenerator(model="gpt-4o-mini"), tools=[web_tool])

# Run the agent with a query
result = agent.run(messages=[ChatMessage.from_user("Find information about Haystack AI framework")])

# Print the final response
print(result["messages"][-1].text)
# Out:
# 2026-01-17T10:54:53.491862Z [error    ] Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:54:54.969864Z [error    ] Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework overview'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework overview'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:54:56.505228Z [error    ] Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework features and applications'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework features and applications'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# It seems that I'm currently unable to access external web search results for the Haystack AI framework. However, I can provide a general overview based on my knowledge.
#
# ### Haystack AI Framework
#
# **Overview:**
# Haystack is an open-source framework designed for building search systems powered by natural language processing (NLP) and machine learning (ML). It allows developers to create and deploy end-to-end search applications, making it easier to handle unstructured data.
#
# **Key Features:**
# 1. **Document Store:** Haystack supports various document stores that allow indexing and searching through documents. You can use databases like Elasticsearch, FAISS, or even traditional databases.
#
# 2. **Pipeline Architecture:** It employs a modular pipeline architecture that enables the chaining of multiple components, such as document retrieval, ranking, and answer generation. This makes it flexible to customize based on use cases.
#
# 3. **Integration with Pre-trained Models:** Haystack can integrate with popular NLP models from libraries like Hugging Face Transformers, enabling tasks such as question answering (QA) and semantic search.
#
# 4. **Support for Multiple Languages:** It's designed to work with multiple languages, accommodating a diverse range of applications globally.
#
# 5. **REST API:** Haystack can run a REST API, allowing seamless integration with web applications and other services.
#
# 6. **Community and Documentation:** Being an open-source project, it has an active community and comprehensive documentation to help developers effectively implement solutions.
#
# ### Applications:
# Haystack is particularly useful for:
# - Building question-answering systems.
# - Implementing semantic search capabilities in applications.
# - Enabling customer support bots that can fetch relevant information from large datasets.
#
# If you need more specific information or have particular questions about Haystack, feel free to ask!

# %%
from haystack.components.generators.utils import print_streaming_chunk

agent = Agent(
    chat_generator=OpenAIChatGenerator(model="gpt-4o-mini"), tools=[web_tool], streaming_callback=print_streaming_chunk
)

result = agent.run(messages=[ChatMessage.from_user("Find information about Haystack AI framework")])
# Out:
# [TOOL CALL]
# Tool: web_tool
# Arguments: {"query":"Haystack AI framework information"}
# 2026-01-17T10:42:16.479629Z [error    ] Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework information'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework information'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# [TOOL RESULT]
# Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework information'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search
#
# [TOOL CALL]
# Tool: web_tool
# Arguments: {"query":"Haystack AI framework"}
# 2026-01-17T10:42:18.931784Z [error    ] Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# [TOOL RESULT]
# Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search
#
# [TOOL CALL]
# Tool: web_tool
# Arguments: {"query":"Haystack AI framework overview"}
# 2026-01-17T10:42:21.291713Z [error    ] Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework overview'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework overview'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# [TOOL RESULT]
# Failed to invoke Tool `web_tool` with parameters {'query': 'Haystack AI framework overview'}. Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search
#
# [ASSISTANT]
# I am currently unable to access external web resources for information. However, I can provide a general overview of the Haystack AI framework based on my training data.
#
# Haystack is an open-source framework designed to facilitate the development of AI-powered search systems, particularly for integrating natural language processing (NLP) into various applications. It allows developers to build pipelines that can process and retrieve information from various data sources, enabling efficient information retrieval and question-answering functionalities.
#
# Key features of the Haystack framework include:
#
# 1. **Modularity**: Haystack provides a modular architecture, allowing developers to easily swap components, such as document stores, retrievers, and readers.
#
# 2. **Support for Various Backends**: The framework can work with different data storage solutions, such as Elasticsearch, OpenSearch, and SQL databases, making it flexible for various use cases.
#
# 3. **Integrations with Models**: Haystack integrates well with pre-trained transformer models like BERT and RoBERTa, enabling advanced natural language understanding.
#
# 4. **Distributed Processing**: The framework supports distributed processing, which is essential for working with large datasets.
#
# 5. **Community and Documentation**: Being an open-source project, Haystack has a growing community, and its documentation provides extensive resources for getting started and advanced usage.
#
# If you need more specific information or details about certain aspects of Haystack, feel free to ask!

# %% [markdown]
# # Using Agent with a Pipeline as Tool

# %%
from haystack.components.builders.answer_builder import AnswerBuilder
from haystack.components.converters.html import HTMLToDocument
from haystack.components.converters.output_adapter import OutputAdapter
from haystack.components.fetchers.link_content import LinkContentFetcher
from haystack.components.websearch.serper_dev import SerperDevWebSearch
from haystack.dataclasses import ChatMessage
from haystack.core.pipeline import Pipeline

search_pipeline = Pipeline()

search_pipeline.add_component("search", SerperDevWebSearch(top_k=10))
search_pipeline.add_component("fetcher", LinkContentFetcher(timeout=3, raise_on_failure=False, retry_attempts=2))
search_pipeline.add_component("converter", HTMLToDocument())
search_pipeline.add_component(
    "output_adapter",
    OutputAdapter(
        template="""
{%- for doc in docs -%}
  {%- if doc.content -%}
  <search-result url="{{ doc.meta.url }}">
  {{ doc.content|truncate(25000) }}
  </search-result>
  {%- endif -%}
{%- endfor -%}
""",
        output_type=str,
    ),
)

search_pipeline.connect("search.links", "fetcher.urls")
search_pipeline.connect("fetcher.streams", "converter.sources")
search_pipeline.connect("converter.documents", "output_adapter.docs")
# Out:
# <haystack.core.pipeline.pipeline.Pipeline object at 0x0000018129C120F0>
# 🚅 Components
#   - search: SerperDevWebSearch
#   - fetcher: LinkContentFetcher
#   - converter: HTMLToDocument
#   - output_adapter: OutputAdapter
# 🛤️ Connections
#   - search.links -> fetcher.urls (list[str])
#   - fetcher.streams -> converter.sources (list[ByteStream])
#   - converter.documents -> output_adapter.docs (list[Document])

# %% [markdown]
# ## Creating a Tool from a Pipeline

# %%
from haystack.core.super_component import SuperComponent
from haystack.tools import ComponentTool
from haystack.components.agents import Agent
from haystack.components.generators.chat import OpenAIChatGenerator

search_component = SuperComponent(
    pipeline=search_pipeline,
    input_mapping={"query": ["search.query"]},
    output_mapping={"output_adapter.output": "search_result"},
)

search_tool = ComponentTool(
    name="search",
    description="Use this tool to search for information on the internet.",
    component=search_component,
    outputs_to_string={"source": "search_result"},
)

agent = Agent(
    chat_generator=OpenAIChatGenerator(model="gpt-4o-mini"),
    tools=[search_tool],
    system_prompt="""
    You are a deep research assistant.
    You create comprehensive research reports to answer the user's questions.
    You use the 'search'-tool to answer any questions.
    You perform multiple searches until you have the information you need to answer the question.
    Make sure you research different aspects of the question.
    Use markdown to format your response.
    When you use information from the websearch results, cite your sources using markdown links.
    It is important that you cite accurately.
    """,
    exit_conditions=["text"],
    max_agent_steps=20,
)

# %%
query = "What are the latest updates on the Artemis moon mission?"
messages = [ChatMessage.from_user(query)]

agent.warm_up()
agent_output = agent.run(messages=messages)

print(agent_output["messages"][-1].text)
# Out:
# 2026-01-17T10:44:58.043180Z [error    ] Failed to invoke Tool `search` with parameters {'query': 'latest updates Artemis moon mission October 2023'}. Error: The following component failed to run:
# Component name: 'search'
# Component type: 'SerperDevWebSearch'
# Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `search` with parameters {'query': 'latest updates Artemis moon mission October 2023'}. Error: The following component failed to run:\nComponent name: 'search'\nComponent type: 'SerperDevWebSearch'\nError: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:44:59.509297Z [error    ] Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission updates October 2023'}. Error: The following component failed to run:
# Component name: 'search'
# Component type: 'SerperDevWebSearch'
# Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission updates October 2023'}. Error: The following component failed to run:\nComponent name: 'search'\nComponent type: 'SerperDevWebSearch'\nError: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:45:00.849782Z [error    ] Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission news October 2023'}. Error: The following component failed to run:
# Component name: 'search'
# Component type: 'SerperDevWebSearch'
# Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission news October 2023'}. Error: The following component failed to run:\nComponent name: 'search'\nComponent type: 'SerperDevWebSearch'\nError: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:45:02.784665Z [error    ] Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission recent news October 2023'}. Error: The following component failed to run:
# Component name: 'search'
# Component type: 'SerperDevWebSearch'
# Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission recent news October 2023'}. Error: The following component failed to run:\nComponent name: 'search'\nComponent type: 'SerperDevWebSearch'\nError: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:45:04.991447Z [error    ] Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission summary news October 2023'}. Error: The following component failed to run:
# Component name: 'search'
# Component type: 'SerperDevWebSearch'
# Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `search` with parameters {'query': 'Artemis moon mission summary news October 2023'}. Error: The following component failed to run:\nComponent name: 'search'\nComponent type: 'SerperDevWebSearch'\nError: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:45:06.470521Z [error    ] Failed to invoke Tool `search` with parameters {'query': 'NASA Artemis moon mission updates October 2023'}. Error: The following component failed to run:
# Component name: 'search'
# Component type: 'SerperDevWebSearch'
# Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `search` with parameters {'query': 'NASA Artemis moon mission updates October 2023'}. Error: The following component failed to run:\nComponent name: 'search'\nComponent type: 'SerperDevWebSearch'\nError: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# 2026-01-17T10:45:08.922364Z [error    ] Failed to invoke Tool `search` with parameters {'query': 'latest Artemis mission news 2023'}. Error: The following component failed to run:
# Component name: 'search'
# Component type: 'SerperDevWebSearch'
# Error: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search error_exception=ToolInvocationError("Failed to invoke Tool `search` with parameters {'query': 'latest Artemis mission news 2023'}. Error: The following component failed to run:\nComponent name: 'search'\nComponent type: 'SerperDevWebSearch'\nError: An error occurred while querying SerperDevWebSearch. Error: 403 Client Error: Forbidden for url: https://google.serper.dev/search") lineno=619 module=haystack.components.tools.tool_invoker
# It seems that I am currently unable to access the latest web search results for updates on the Artemis moon mission. However, based on what I know up to October 2023, here are some key points regarding the Artemis program:
#
# ### Artemis Program Overview
# The Artemis program is NASA's initiative to return humans to the Moon and establish a sustainable human presence there by the end of the decade. The program aims to land the first woman and the next man on the lunar surface, as well as to enable long-term exploration and scientific research.
#
# ### Recent Key Milestones
# 1. **Artemis I Mission**: The uncrewed mission successfully launched in November 2021 and completed a 25.5-day journey around the Moon, marking a crucial test for subsequent missions.
#
# 2. **Artemis II Mission**: Scheduled as the first crewed mission in the Artemis program, Artemis II aims to send astronauts on a mission to orbit the Moon. Preparations are ongoing, and this mission is expected to launch in 2024.
#
# 3. **Artemis III Mission**: This mission is intended for landing astronauts on the lunar South Pole, with plans to occur in 2025, depending on the timelines of preceding missions and technologies.
#
# 4. **NASA's Lunar Gateway**: The development of the Lunar Gateway, a space station in lunar orbit that will support human and robotic missions to the Moon and beyond, is also progressing.
#
# 5. **Collaborations and Partnerships**: NASA is engaging with international partners and commercial entities to enhance capabilities for lunar exploration.
#
# ### Goals and Future Outlook
# - **Sustainability**: The Artemis program focuses on creating sustainable human exploration of the Moon, preparing for Mars missions.
# - **Research and Technology Development**: Ongoing tests and developments are being made in areas such as lunar landers, habitats, and surface mobility.
# - **Science**: Each mission endeavors to collect lunar samples and conduct scientific research that can lead to deeper insights about the Moon and the solar system.
#
# For the most current updates on timelines, missions, and technology, I recommend checking NASA's official Artemis page or news outlets specializing in aerospace and technology. Would you like more detailed information on a specific aspect of the Artemis program?

# %%
from IPython.display import Markdown, display

display(Markdown(agent_output["messages"][-1].text))
# Out:
# It seems that I am currently unable to access the latest web search results for updates on the Artemis moon mission. However, based on what I know up to October 2023, here are some key points regarding the Artemis program:
#
# ### Artemis Program Overview
# The Artemis program is NASA's initiative to return humans to the Moon and establish a sustainable human presence there by the end of the decade. The program aims to land the first woman and the next man on the lunar surface, as well as to enable long-term exploration and scientific research.
#
# ### Recent Key Milestones
# 1. **Artemis I Mission**: The uncrewed mission successfully launched in November 2021 and completed a 25.5-day journey around the Moon, marking a crucial test for subsequent missions.
#
# 2. **Artemis II Mission**: Scheduled as the first crewed mission in the Artemis program, Artemis II aims to send astronauts on a mission to orbit the Moon. Preparations are ongoing, and this mission is expected to launch in 2024.
#
# 3. **Artemis III Mission**: This mission is intended for landing astronauts on the lunar South Pole, with plans to occur in 2025, depending on the timelines of preceding missions and technologies.
#
# 4. **NASA's Lunar Gateway**: The development of the Lunar Gateway, a space station in lunar orbit that will support human and robotic missions to the Moon and beyond, is also progressing.
#
# 5. **Collaborations and Partnerships**: NASA is engaging with international partners and commercial entities to enhance capabilities for lunar exploration.
#
# ### Goals and Future Outlook
# - **Sustainability**: The Artemis program focuses on creating sustainable human exploration of the Moon, preparing for Mars missions.
# - **Research and Technology Development**: Ongoing tests and developments are being made in areas such as lunar landers, habitats, and surface mobility.
# - **Science**: Each mission endeavors to collect lunar samples and conduct scientific research that can lead to deeper insights about the Moon and the solar system.
#
# For the most current updates on timelines, missions, and technology, I recommend checking NASA's official Artemis page or news outlets specializing in aerospace and technology. Would you like more detailed information on a specific aspect of the Artemis program?

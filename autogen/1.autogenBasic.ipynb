# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv 
import os 

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # Connecting to the model

# %%
model_client = OpenAIChatCompletionClient(model="gpt-4")

# %% [markdown]
# # Building the Agent

# %%
assistant = AssistantAgent(name= "my_assistant", model_client= model_client)

# %% [markdown]
# # Asking the agent A question

# %%
result = await assistant.run(task = "tell me a fun fact about space")
print(result)
# Out:
# messages=[TextMessage(source='user', models_usage=None, metadata={}, content='tell me a fun fact about space', type='TextMessage'), TextMessage(source='my_assistant', models_usage=RequestUsage(prompt_tokens=43, completion_tokens=50), metadata={}, content="Sure, here's a fun fact about space: In space, astronauts cannot cry because there is no gravity, thus tears can't flow. Their eyes can produce tears but they stick as tiny liquid balls and can make vision blurry. \nTERMINATE", type='TextMessage')] stop_reason=None

# %%
print(result.messages[-1].content)
# Out:
# Sure, here's a fun fact about space: In space, astronauts cannot cry because there is no gravity, thus tears can't flow. Their eyes can produce tears but they stick as tiny liquid balls and can make vision blurry.
# TERMINATE
